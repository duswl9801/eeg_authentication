# %%
import scipy.io
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
from tensorflow.keras.callbacks import  EarlyStopping
import random

# 기존 train 데이터 불러오기
# [11, 505000, 2]
train_sub_data = scipy.io.loadmat('../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']

# 퍼블릭 데이터 불러오기
# [109, 9600, 2]
public_data = scipy.io.loadmat('../datas/160hz/Motor_Imagery.mat', squeeze_me=True)['data']

# 기존 test 데이터 불러오기
# [11, 101402, 2]
test_sub_data = scipy.io.loadmat('../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# # 데이터를 480(= 160*3) 크기로 사용할 수 있도록 그 배수로 전체 데이터 잘라줌
data_cut_size = 504960 # 480*1052 = 504960
public_cut_size = 9600 # 480*20 = 9600
test_cut_size = 101280 # 480*211 = 101280

# 트레인 sub 수
train_sub_cnt = train_sub_data.shape[0]
# 퍼블릭 데이터 sub 수
public_sub_cnt = public_data.shape[0]
# test 데이터 sub 수
test_sub_cnt = test_sub_data.shape[0]

sub_cnt = train_sub_cnt + public_sub_cnt

train_sub_cut = train_sub_data[:, 0:data_cut_size, :]
public_data_cut = public_data[:, 0:public_cut_size, :]
test_sub_cut = test_sub_data[:, 0:test_cut_size, :]

print(train_sub_cut.shape)
print(test_sub_cut.shape)
print(public_data_cut.shape)

# 데이터를 스케일링 하기 위해 2D로 reshape
train_sub_2D = train_sub_cut.reshape(-1, 1)
public_data_2D = public_data_cut.reshape(-1, 1)
test_2D = test_sub_cut.reshape(-1, 1)

# 데이터를 StandardScaler로 스케일링
# 데이터들 모두 같은 방식으로 스케일링함
SDscaler = StandardScaler()
SDscaler.fit(train_sub_2D)
train_scaled = SDscaler.transform(train_sub_2D)
test_scaled = SDscaler.transform(test_2D)
public_scaled = SDscaler.transform(public_data_2D)

# 데이터 크기를 480로 맞춰줌
# 5554560/480 = 115,72
data_size = 480
train_sub_size = 1052 # 1명당 3초 데이터 1052개
public_sub_size = 20
test_sub_size = 211

train_data = train_scaled.reshape(train_sub_cnt * train_sub_size, data_size, 2)
public_data = public_scaled.reshape(public_sub_cnt * public_sub_size, data_size, 2)
test_data = test_scaled.reshape(test_sub_cnt * test_sub_size, data_size, 2)

print(train_data.shape)
print(public_data.shape)
print(test_data.shape)

#test data를 sub:other=1:1로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(test_sub_cnt):
    test_data_each.insert(i, test_data[i*test_sub_size:(i+1)*test_sub_size, :, :])
# print(test_data_each)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(train_sub_cnt):
    train_data_each.insert(i, train_data[i*train_sub_size:(i+1)*train_sub_size, :, :])
    
public_data_each = []
for i in range(public_sub_cnt):
    public_data_each.insert(i, public_data[i*public_sub_size:(i+1)*public_sub_size, :, :])
# Out:
# (11, 504960, 2)
# (11, 101280, 2)
# (109, 9600, 2)
# (11572, 480, 2)
# (2180, 480, 2)
# (2321, 480, 2)

# %%
# 평가 지표
test_pre_all = []
conf_mat_all = []
test_loss_all = []
test_acc_all = []
test_sen_all = []
test_spe_all = []
frr_all = []
far_all = []

# %%
# 각 sub 마다 모델 학습

# train data를 sub:other = 1:2로 만들기
# 3초 덩어리 개수 1052 : 2104
# 17 * 38 + 18 * 81 = 2104

# test data를 sub:other = 1:2로 만들기
# 3초 덩어리 개수 211 : 422
# 42 * 8 + 43 * 2 = 422

for i in range(train_sub_cnt):
    cnt = 0
    train_data_n = train_data_each[i]
    test_data_n = test_data_each[i]
    
    for j in range(sub_cnt):
        if j != i and cnt < 38:
            cnt = cnt + 1
            if j < 11:
                train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 17)), axis = 0)
            else:
                train_data_n = np.append(train_data_n, np.array(random.sample(list(public_data_each[j-11]), 17)), axis = 0)
        elif j != i and cnt >= 38:
            train_data_n = np.append(train_data_n, np.array(random.sample(list(public_data_each[j-11]), 18)), axis = 0)
    
    cnt = 0
    
    for j in range(test_sub_cnt):
        if j != i and cnt < 8:
            cnt = cnt + 1
            test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 42)), axis = 0)
        elif j != i and cnt >= 8:
            test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 43)), axis = 0)
            
    print(train_data_n.shape)
    print(test_data_n.shape)
    
    train_label = np.zeros(3156)
    test_label = np.zeros(633)
    
    for j in range(len(train_label)):
        if (j < train_sub_size):
            train_label[j] = 1
            
    for j in range(len(test_label)):
        if (j < test_sub_size):
            test_label[j] = 1
            
    ################################################################
    # 모델 구성하기                                                #
    # 이진 분류이기 때문에 0~1 사이의 값을 나타내는 출력뉴런 1개   #
    ################################################################

    # Cnn 층
    inputs = tf.keras.Input(shape = (480, 2))

    layers = tf.keras.layers.Conv1D(filters = 16, kernel_size = 3, strides = 1, padding = 'same', activation  = 'relu')(inputs)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    layers = tf.keras.layers.Conv1D(filters = 32, kernel_size = 3, strides = 1, padding = 'same', activation  = 'relu')(layers)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    layers = tf.keras.layers.Conv1D(filters = 64, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(layers)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    # LSTM 층
    layers = tf.keras.layers.LSTM(64)(layers)

    # Dense 층
    layers = tf.keras.layers.Dropout(0.3)(layers)
    layers = tf.keras.layers.Dense(128, activation='relu')(layers)
    # layers = tf.keras.layers.Dropout(0.01)(layers)
    layers = tf.keras.layers.Dense(64, activation='relu')(layers)
    # layers = tf.keras.layers.Dropout(0.05)(layers)
    layers = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.models.Model(inputs = inputs, outputs = layers)
    model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.Adam(0.005), metrics=['accuracy'])
    model.summary()
    
    early_stopping = tf.keras.callbacks.EarlyStopping(patience= 20)
    
#     # train 데이터를 train과 validation으로 분배
#     # validation 데이터를 여러 sub에서 가져갈 수 있도록 shuffle
#     x_train, x_val, y_train, y_val = train_test_split(train_data, train_label, test_size=0.1, shuffle=True, random_state=1)

    print('##########')
    print('# sub', i+1, ' #')
    print('##########')

    # 모델 돌리기
#     hist = model.fit(x_train, y_train, batch_size=40, epochs=200, validation_data=(x_val, y_val), verbose=1, callbacks= [early_stopping])
    hist = model.fit(train_data_n, train_label, batch_size=20, epochs=100, verbose=1)
    
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()
    
    loss_ax.plot(hist.history['loss'], 'y', label = 'train loss')
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    loss_ax.legend(loc='upper left')
    
    
    acc_ax.plot(hist.history['accuracy'], 'b', label = 'train acc')
    acc_ax.set_ylabel('acc')
    acc_ax.legend(loc='upper left')
    
    plt.show()
    
    # save model
    model.save('Sub_Model_' + str(i + 1) + '.h5')
    
    test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose= 2)
    test_pred = model.predict(test_data_n)
    
    test_loss_all.append(test_loss)
    test_acc_all.append(test_acc)
    
    # 확률이 0.5이상이면 자신(1), 작으면 타인(0)
    for i in range(len(test_pred)):
        if(0.5 <= test_pred[i]):
            test_pred[i] = 1

        else:
            test_pred[i] = 0
            
            
    test_pre_all.append(test_pred)
    
    # confusion matrix 생성
    conf_matrix = confusion_matrix(test_label, test_pred)
    
    #############################################################
    #       conf_matrix[0][0] = TN      conf_matrix[0][1] = FP  #
    #       conf_matrix[1][0] = FN      conf_matrix[1][1] = TP  #
    #############################################################

    print(conf_matrix)
    conf_mat_all.append(conf_matrix)

    # sum 이용 각 행 더하기
    row = conf_matrix.sum(axis=1)
    print('\n', row)

    # row[0] = spec의 분모, row[1] = sens의 분모

    test_sensitivity = conf_matrix[1][1] / row[1]
    test_specificity = conf_matrix[0][0] / row[0]
    
    test_frr = conf_matrix[1][0] / (conf_matrix[1][1]+conf_matrix[1][0])
    test_far = conf_matrix[0][1] / (conf_matrix[0][1]+conf_matrix[0][0])

    print('sensitivity : ', test_sensitivity)
    print('specificity : ', test_specificity) 
    print('frr : ', test_frr)
    print('far : ', test_far) 
    
    test_sen_all.append(test_sensitivity)
    test_spe_all.append(test_specificity)
    frr_all.append(test_frr)
    far_all.append(test_far)
    
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111)

    cax = ax.matshow(conf_matrix)

    fig.colorbar(cax)

    for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
        plt.text(j, i, conf_matrix[i, j], color="white")

    plt.title('CNN+LSTM model')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')

    plt.show()
    
print('average_accuracy')
print(np.mean(test_acc_all))
print('average_sensitivity')
print(np.mean(test_sen_all))
print('average_specificity')
print(np.mean(test_spe_all))
print('average_frr')
print(np.mean(frr_all))
print('average_far')
print(np.mean(far_all))
# Out:
# (3156, 480, 2)
# (633, 480, 2)
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 1  #
# ##########
# Epoch 1/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1960 - accuracy: 0.9236
# Epoch 2/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1418 - accuracy: 0.9480
# Epoch 3/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1209 - accuracy: 0.9503
# Epoch 4/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1172 - accuracy: 0.9550
# Epoch 5/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1021 - accuracy: 0.9645
# Epoch 6/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0956 - accuracy: 0.9632
# Epoch 7/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1024 - accuracy: 0.9658
# Epoch 8/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0947 - accuracy: 0.9686
# Epoch 9/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1134 - accuracy: 0.9572
# Epoch 10/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0885 - accuracy: 0.9705
# Epoch 11/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0877 - accuracy: 0.9686
# Epoch 12/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0856 - accuracy: 0.9712
# Epoch 13/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0783 - accuracy: 0.9740
# Epoch 14/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0743 - accuracy: 0.9747
# Epoch 15/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0703 - accuracy: 0.9778
# Epoch 16/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0746 - accuracy: 0.9756
# Epoch 17/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0655 - accuracy: 0.9785
# Epoch 18/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0622 - accuracy: 0.9794
# Epoch 19/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0663 - accuracy: 0.9778
# Epoch 20/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0602 - accuracy: 0.9829
# Epoch 21/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0522 - accuracy: 0.9826
# Epoch 22/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0478 - accuracy: 0.9864
# Epoch 23/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0372 - accuracy: 0.9895
# Epoch 24/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0491 - accuracy: 0.9861
# Epoch 25/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0836 - accuracy: 0.9740
# Epoch 26/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0665 - accuracy: 0.9813
# Epoch 27/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0439 - accuracy: 0.9870
# Epoch 28/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0416 - accuracy: 0.9861
# Epoch 29/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0542 - accuracy: 0.9845
# Epoch 30/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0433 - accuracy: 0.9854
# Epoch 31/100
# 158/158 [==============================] - 2s 9ms/step - loss: 0.0345 - accuracy: 0.9886
# Epoch 32/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0281 - accuracy: 0.9927
# Epoch 33/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0375 - accuracy: 0.9883
# Epoch 34/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0382 - accuracy: 0.9889
# Epoch 35/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0405 - accuracy: 0.9867
# Epoch 36/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0378 - accuracy: 0.9880
# Epoch 37/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0275 - accuracy: 0.9924
# Epoch 38/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0457 - accuracy: 0.9826
# Epoch 39/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0280 - accuracy: 0.9911
# Epoch 40/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0187 - accuracy: 0.9943
# Epoch 41/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0301 - accuracy: 0.9899
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0304 - accuracy: 0.9914
# Epoch 43/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0573 - accuracy: 0.9810
# Epoch 44/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0501 - accuracy: 0.9848
# Epoch 45/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0336 - accuracy: 0.9905
# Epoch 46/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0394 - accuracy: 0.9867
# Epoch 47/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0436 - accuracy: 0.9857
# Epoch 48/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0283 - accuracy: 0.9908
# Epoch 49/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0405 - accuracy: 0.9857
# Epoch 50/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0256 - accuracy: 0.9905
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0434 - accuracy: 0.9870
# Epoch 52/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0479 - accuracy: 0.9823
# Epoch 53/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0138 - accuracy: 0.9949
# Epoch 54/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0456 - accuracy: 0.9892
# Epoch 55/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0196 - accuracy: 0.9940
# Epoch 56/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0248 - accuracy: 0.9937
# Epoch 57/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0266 - accuracy: 0.9927
# Epoch 58/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0165 - accuracy: 0.9949
# Epoch 59/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0360 - accuracy: 0.9870
# Epoch 60/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9937
# Epoch 61/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0144 - accuracy: 0.9952
# Epoch 62/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0221 - accuracy: 0.9914
# Epoch 63/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0501 - accuracy: 0.9842
# Epoch 64/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0352 - accuracy: 0.9886
# Epoch 65/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0386 - accuracy: 0.9851
# Epoch 66/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0162 - accuracy: 0.9940
# Epoch 67/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0352 - accuracy: 0.9892
# Epoch 68/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0624 - accuracy: 0.9772
# Epoch 69/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0399 - accuracy: 0.9870
# Epoch 70/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0346 - accuracy: 0.9870
# Epoch 71/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0466 - accuracy: 0.9845
# Epoch 72/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0311 - accuracy: 0.9902
# Epoch 73/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0163 - accuracy: 0.9940
# Epoch 74/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0409 - accuracy: 0.9845
# Epoch 75/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0343 - accuracy: 0.9873
# Epoch 76/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0383 - accuracy: 0.9864
# Epoch 77/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0262 - accuracy: 0.9905
# Epoch 78/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0240 - accuracy: 0.9918
# Epoch 79/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0230 - accuracy: 0.9946
# Epoch 80/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0386 - accuracy: 0.9880
# Epoch 81/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0477 - accuracy: 0.9832
# Epoch 82/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0784 - accuracy: 0.9781
# Epoch 83/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0563 - accuracy: 0.9810
# Epoch 84/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0377 - accuracy: 0.9845
# Epoch 85/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0269 - accuracy: 0.9911
# Epoch 86/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0153 - accuracy: 0.9943
# Epoch 87/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0178 - accuracy: 0.9937
# Epoch 88/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0225 - accuracy: 0.9914
# Epoch 89/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0401 - accuracy: 0.9873
# Epoch 90/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0143 - accuracy: 0.9952
# Epoch 91/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0252 - accuracy: 0.9908
# Epoch 92/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0388 - accuracy: 0.9851
# Epoch 93/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0735 - accuracy: 0.9756
# Epoch 94/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0841 - accuracy: 0.9702
# Epoch 95/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0369 - accuracy: 0.9876
# Epoch 96/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0379 - accuracy: 0.9864
# Epoch 97/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0293 - accuracy: 0.9908
# Epoch 98/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0277 - accuracy: 0.9921
# Epoch 99/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0323 - accuracy: 0.9876
# Epoch 100/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0215 - accuracy: 0.9933
# 20/20 - 0s - loss: 1.8774 - accuracy: 0.6256
# [[185 237]
#  [  0 211]]
#
#  [422 211]
# sensitivity :  1.0
# specificity :  0.43838862559241704
# frr :  0.0
# far :  0.5616113744075829
# (3156, 480, 2)
# (633, 480, 2)
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_36 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_37 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_37 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_38 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 2  #
# ##########
# Epoch 1/100
# 158/158 [==============================] - 2s 11ms/step - loss: 0.2224 - accuracy: 0.9154
# Epoch 2/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1477 - accuracy: 0.9471
# Epoch 3/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1122 - accuracy: 0.9607
# Epoch 4/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1196 - accuracy: 0.9518
# Epoch 5/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1046 - accuracy: 0.9677
# Epoch 6/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0885 - accuracy: 0.9674
# Epoch 7/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1128 - accuracy: 0.9604
# Epoch 8/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0770 - accuracy: 0.9708
# Epoch 9/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0733 - accuracy: 0.9724
# Epoch 10/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0789 - accuracy: 0.9677
# Epoch 11/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0584 - accuracy: 0.9769
# Epoch 12/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0865 - accuracy: 0.9658
# Epoch 13/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0553 - accuracy: 0.9804
# Epoch 14/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0546 - accuracy: 0.9785
# Epoch 15/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0461 - accuracy: 0.9816
# Epoch 16/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0693 - accuracy: 0.9756
# Epoch 17/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0788 - accuracy: 0.9664
# Epoch 18/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0664 - accuracy: 0.9724
# Epoch 19/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0407 - accuracy: 0.9835
# Epoch 20/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0532 - accuracy: 0.9794
# Epoch 21/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0403 - accuracy: 0.9838
# Epoch 22/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0262 - accuracy: 0.9902
# Epoch 23/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0372 - accuracy: 0.9908
# Epoch 24/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0619 - accuracy: 0.9813
# Epoch 25/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0306 - accuracy: 0.9886
# Epoch 26/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0356 - accuracy: 0.9889
# Epoch 27/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0303 - accuracy: 0.9870
# Epoch 28/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0314 - accuracy: 0.9889
# Epoch 29/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0472 - accuracy: 0.9810
# Epoch 30/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0267 - accuracy: 0.9924
# Epoch 31/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0344 - accuracy: 0.9895
# Epoch 32/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0133 - accuracy: 0.9952
# Epoch 33/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0187 - accuracy: 0.9943
# Epoch 34/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0601 - accuracy: 0.9807
# Epoch 35/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0177 - accuracy: 0.9959
# Epoch 36/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0281 - accuracy: 0.9918
# Epoch 37/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0191 - accuracy: 0.9940
# Epoch 38/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0329 - accuracy: 0.9880
# Epoch 39/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0181 - accuracy: 0.9930
# Epoch 40/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0173 - accuracy: 0.9933
# Epoch 41/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0268 - accuracy: 0.9880
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0273 - accuracy: 0.9911
# Epoch 43/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0155 - accuracy: 0.9959
# Epoch 44/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 45/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1005 - accuracy: 0.9686
# Epoch 46/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0536 - accuracy: 0.9794
# Epoch 47/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0412 - accuracy: 0.9854
# Epoch 48/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0398 - accuracy: 0.9867
# Epoch 49/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0212 - accuracy: 0.9921
# Epoch 50/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0173 - accuracy: 0.9956
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0168 - accuracy: 0.9946
# Epoch 52/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0092 - accuracy: 0.9965
# Epoch 53/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0344 - accuracy: 0.9895
# Epoch 54/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0148 - accuracy: 0.9943
# Epoch 55/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0173 - accuracy: 0.9943
# Epoch 56/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0128 - accuracy: 0.9975
# Epoch 57/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0265 - accuracy: 0.9921
# Epoch 58/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0125 - accuracy: 0.9965
# Epoch 59/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 60/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1009 - accuracy: 0.9750
# Epoch 61/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0302 - accuracy: 0.9895
# Epoch 62/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0094 - accuracy: 0.9968
# Epoch 63/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0139 - accuracy: 0.9956
# Epoch 64/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0402 - accuracy: 0.9883
# Epoch 65/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0414 - accuracy: 0.9899
# Epoch 66/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0148 - accuracy: 0.9962
# Epoch 67/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0157 - accuracy: 0.9949
# Epoch 68/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0140 - accuracy: 0.9968
# Epoch 69/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0112 - accuracy: 0.9949
# Epoch 70/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0246 - accuracy: 0.9918
# Epoch 71/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0092 - accuracy: 0.9965
# Epoch 72/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9975
# Epoch 73/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0216 - accuracy: 0.9940
# Epoch 74/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0128 - accuracy: 0.9952
# Epoch 75/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0252 - accuracy: 0.9937
# Epoch 76/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0179 - accuracy: 0.9959
# Epoch 77/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0258 - accuracy: 0.9914
# Epoch 78/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0155 - accuracy: 0.9949
# Epoch 79/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0209 - accuracy: 0.9927
# Epoch 80/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0093 - accuracy: 0.9962
# Epoch 81/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 82/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0163 - accuracy: 0.9975
# Epoch 83/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0116 - accuracy: 0.9971
# Epoch 84/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0056 - accuracy: 0.9994
# Epoch 85/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0101 - accuracy: 0.9968
# Epoch 86/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 87/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0136 - accuracy: 0.9956
# Epoch 88/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0055 - accuracy: 0.9975
# Epoch 89/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0438 - accuracy: 0.9889
# Epoch 90/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0548 - accuracy: 0.9794
# Epoch 91/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0181 - accuracy: 0.9968
# Epoch 92/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 93/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0088 - accuracy: 0.9968
# Epoch 94/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0157 - accuracy: 0.9946
# Epoch 95/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0053 - accuracy: 0.9981
# Epoch 96/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0290 - accuracy: 0.9908
# Epoch 97/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0108 - accuracy: 0.9965
# Epoch 98/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0307 - accuracy: 0.9905
# Epoch 99/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9987
# Epoch 100/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0201 - accuracy: 0.9940
# 20/20 - 0s - loss: 1.1591 - accuracy: 0.7725
# [[284 138]
#  [  6 205]]
#
#  [422 211]
# sensitivity :  0.9715639810426541
# specificity :  0.6729857819905213
# frr :  0.02843601895734597
# far :  0.32701421800947866
# (3156, 480, 2)
# (633, 480, 2)
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_40 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_40 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_41 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_41 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_40 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 3  #
# ##########
# Epoch 1/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.2194 - accuracy: 0.9167
# Epoch 2/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1621 - accuracy: 0.9430
# Epoch 3/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1362 - accuracy: 0.9550
# Epoch 4/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1278 - accuracy: 0.9579
# Epoch 5/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1221 - accuracy: 0.9575
# Epoch 6/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1249 - accuracy: 0.9534
# Epoch 7/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1183 - accuracy: 0.9588
# Epoch 8/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1386 - accuracy: 0.9525
# Epoch 9/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1108 - accuracy: 0.9620
# Epoch 10/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1004 - accuracy: 0.9702
# Epoch 11/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0979 - accuracy: 0.9702
# Epoch 12/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0877 - accuracy: 0.9696
# Epoch 13/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0898 - accuracy: 0.9686
# Epoch 14/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0893 - accuracy: 0.9680
# Epoch 15/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0910 - accuracy: 0.9686
# Epoch 16/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0845 - accuracy: 0.9715
# Epoch 17/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0882 - accuracy: 0.9721
# Epoch 18/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0914 - accuracy: 0.9699
# Epoch 19/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0810 - accuracy: 0.9743
# Epoch 20/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0765 - accuracy: 0.9737
# Epoch 21/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0658 - accuracy: 0.9737
# Epoch 22/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0520 - accuracy: 0.9800
# Epoch 23/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0488 - accuracy: 0.9848
# Epoch 24/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0390 - accuracy: 0.9851
# Epoch 25/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0596 - accuracy: 0.9759
# Epoch 26/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0407 - accuracy: 0.9848
# Epoch 27/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0425 - accuracy: 0.9832
# Epoch 28/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0644 - accuracy: 0.9788
# Epoch 29/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0380 - accuracy: 0.9873
# Epoch 30/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0439 - accuracy: 0.9845
# Epoch 31/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0400 - accuracy: 0.9832
# Epoch 32/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0349 - accuracy: 0.9867
# Epoch 33/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0314 - accuracy: 0.9889
# Epoch 34/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0391 - accuracy: 0.9854
# Epoch 35/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0363 - accuracy: 0.9848
# Epoch 36/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0316 - accuracy: 0.9895
# Epoch 37/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0275 - accuracy: 0.9908
# Epoch 38/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0261 - accuracy: 0.9911
# Epoch 39/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0502 - accuracy: 0.9835
# Epoch 40/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0331 - accuracy: 0.9873
# Epoch 41/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0201 - accuracy: 0.9952
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0338 - accuracy: 0.9889
# Epoch 43/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0280 - accuracy: 0.9905
# Epoch 44/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0302 - accuracy: 0.9895
# Epoch 45/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9933
# Epoch 46/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.9949
# Epoch 47/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0098 - accuracy: 0.9965
# Epoch 48/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0225 - accuracy: 0.9930
# Epoch 49/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0090 - accuracy: 0.9962
# Epoch 50/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0289 - accuracy: 0.9924
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0324 - accuracy: 0.9905
# Epoch 52/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0401 - accuracy: 0.9883
# Epoch 53/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0166 - accuracy: 0.9962
# Epoch 54/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 55/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0264 - accuracy: 0.9911
# Epoch 56/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0256 - accuracy: 0.9924
# Epoch 57/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0068 - accuracy: 0.9975
# Epoch 58/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0208 - accuracy: 0.9927
# Epoch 59/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0150 - accuracy: 0.9959
# Epoch 60/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0054 - accuracy: 0.9978
# Epoch 61/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0265 - accuracy: 0.9918
# Epoch 62/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0065 - accuracy: 0.9984
# Epoch 63/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0363 - accuracy: 0.9886
# Epoch 64/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0067 - accuracy: 0.9981
# Epoch 65/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0927 - accuracy: 0.9747
# Epoch 66/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0266 - accuracy: 0.9911
# Epoch 67/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0480 - accuracy: 0.9829
# Epoch 68/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0324 - accuracy: 0.9905
# Epoch 69/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0292 - accuracy: 0.9899
# Epoch 70/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0121 - accuracy: 0.9952
# Epoch 71/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0299 - accuracy: 0.9883
# Epoch 72/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0131 - accuracy: 0.9959
# Epoch 73/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0041 - accuracy: 0.9990
# Epoch 74/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0068 - accuracy: 0.9975
# Epoch 75/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0214 - accuracy: 0.9930
# Epoch 76/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0234 - accuracy: 0.9924
# Epoch 77/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0093 - accuracy: 0.9968
# Epoch 78/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0244 - accuracy: 0.9895
# Epoch 79/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0309 - accuracy: 0.9895
# Epoch 80/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9937
# Epoch 81/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0297 - accuracy: 0.9908
# Epoch 82/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0367 - accuracy: 0.9880
# Epoch 83/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0290 - accuracy: 0.9905
# Epoch 84/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0332 - accuracy: 0.9870
# Epoch 85/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0098 - accuracy: 0.9965
# Epoch 86/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0559 - accuracy: 0.9816
# Epoch 87/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0098 - accuracy: 0.9968
# Epoch 88/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0199 - accuracy: 0.9937
# Epoch 89/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0143 - accuracy: 0.9949
# Epoch 90/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0107 - accuracy: 0.9959
# Epoch 91/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1182 - accuracy: 0.9617
# Epoch 92/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1207 - accuracy: 0.9636
# Epoch 93/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0503 - accuracy: 0.9813
# Epoch 94/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0475 - accuracy: 0.9845
# Epoch 95/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0439 - accuracy: 0.9845
# Epoch 96/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 97/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0277 - accuracy: 0.9914
# Epoch 98/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0232 - accuracy: 0.9937
# Epoch 99/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0286 - accuracy: 0.9899
# Epoch 100/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0302 - accuracy: 0.9911
# 20/20 - 0s - loss: 0.6568 - accuracy: 0.7709
# [[280 142]
#  [  3 208]]
#
#  [422 211]
# sensitivity :  0.985781990521327
# specificity :  0.6635071090047393
# frr :  0.014218009478672985
# far :  0.33649289099526064
# (3156, 480, 2)
# (633, 480, 2)
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_42 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_43 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_44 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 4  #
# ##########
# Epoch 1/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1886 - accuracy: 0.9211
# Epoch 2/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1434 - accuracy: 0.9493
# Epoch 3/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1330 - accuracy: 0.9515
# Epoch 4/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1049 - accuracy: 0.9648
# Epoch 5/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1133 - accuracy: 0.9639
# Epoch 6/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1432 - accuracy: 0.9617
# Epoch 7/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1254 - accuracy: 0.9572
# Epoch 8/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1012 - accuracy: 0.9658
# Epoch 9/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0966 - accuracy: 0.9667
# Epoch 10/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1027 - accuracy: 0.9636
# Epoch 11/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0967 - accuracy: 0.9651
# Epoch 12/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0879 - accuracy: 0.9712
# Epoch 13/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0900 - accuracy: 0.9667
# Epoch 14/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0836 - accuracy: 0.9715
# Epoch 15/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0741 - accuracy: 0.9743
# Epoch 16/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0789 - accuracy: 0.9715
# Epoch 17/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0733 - accuracy: 0.9756
# Epoch 18/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0795 - accuracy: 0.9731
# Epoch 19/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0660 - accuracy: 0.9750
# Epoch 20/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0744 - accuracy: 0.9743
# Epoch 21/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0624 - accuracy: 0.9794
# Epoch 22/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0574 - accuracy: 0.9797
# Epoch 23/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0595 - accuracy: 0.9807
# Epoch 24/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0587 - accuracy: 0.9797
# Epoch 25/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0665 - accuracy: 0.9756
# Epoch 26/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0523 - accuracy: 0.9819
# Epoch 27/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0483 - accuracy: 0.9845
# Epoch 28/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0482 - accuracy: 0.9832
# Epoch 29/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0442 - accuracy: 0.9845
# Epoch 30/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0601 - accuracy: 0.9791
# Epoch 31/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0444 - accuracy: 0.9838
# Epoch 32/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0294 - accuracy: 0.9892
# Epoch 33/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0421 - accuracy: 0.9867
# Epoch 34/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0381 - accuracy: 0.9816
# Epoch 35/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0408 - accuracy: 0.9864
# Epoch 36/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0402 - accuracy: 0.9880
# Epoch 37/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0361 - accuracy: 0.9854
# Epoch 38/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0399 - accuracy: 0.9886
# Epoch 39/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0284 - accuracy: 0.9892
# Epoch 40/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0278 - accuracy: 0.9905
# Epoch 41/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0381 - accuracy: 0.9883
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0430 - accuracy: 0.9826
# Epoch 43/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0225 - accuracy: 0.9911
# Epoch 44/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0272 - accuracy: 0.9914
# Epoch 45/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0270 - accuracy: 0.9895
# Epoch 46/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0191 - accuracy: 0.9946
# Epoch 47/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0256 - accuracy: 0.9908
# Epoch 48/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0127 - accuracy: 0.9962
# Epoch 49/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0306 - accuracy: 0.9921
# Epoch 50/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0640 - accuracy: 0.9740
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0296 - accuracy: 0.9905
# Epoch 52/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0145 - accuracy: 0.9956
# Epoch 53/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0472 - accuracy: 0.9838
# Epoch 54/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0252 - accuracy: 0.9899
# Epoch 55/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9984
# Epoch 56/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0290 - accuracy: 0.9921
# Epoch 57/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0206 - accuracy: 0.9940
# Epoch 58/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0197 - accuracy: 0.9924
# Epoch 59/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 60/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0339 - accuracy: 0.9902
# Epoch 61/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0103 - accuracy: 0.9971
# Epoch 62/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0160 - accuracy: 0.9940
# Epoch 63/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0118 - accuracy: 0.9962
# Epoch 64/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 65/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0062 - accuracy: 0.9984
# Epoch 66/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0071 - accuracy: 0.9971
# Epoch 67/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0369 - accuracy: 0.9908
# Epoch 68/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0295 - accuracy: 0.9902
# Epoch 69/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0370 - accuracy: 0.9873
# Epoch 70/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0245 - accuracy: 0.9911
# Epoch 71/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0116 - accuracy: 0.9971
# Epoch 72/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0282 - accuracy: 0.9908
# Epoch 73/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0094 - accuracy: 0.9965
# Epoch 74/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0203 - accuracy: 0.9933
# Epoch 75/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0086 - accuracy: 0.9965
# Epoch 76/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0196 - accuracy: 0.9952
# Epoch 77/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0135 - accuracy: 0.9968
# Epoch 78/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0093 - accuracy: 0.9975
# Epoch 79/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0052 - accuracy: 0.9984
# Epoch 80/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9978
# Epoch 81/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0168 - accuracy: 0.9946
# Epoch 82/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0128 - accuracy: 0.9968
# Epoch 83/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0114 - accuracy: 0.9965
# Epoch 84/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0087 - accuracy: 0.9978
# Epoch 85/100
# ...
# Epoch 70/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0097 - accuracy: 0.9962
# Epoch 71/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0092 - accuracy: 0.9962
# Epoch 72/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 73/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.9984
# Epoch 74/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0105 - accuracy: 0.9962
# Epoch 75/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 76/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0020 - accuracy: 0.9997
# Epoch 77/100
# 158/158 [==============================] - 1s 9ms/step - loss: 8.0538e-05 - accuracy: 1.0000
# Epoch 78/100
# 158/158 [==============================] - 1s 9ms/step - loss: 2.4827e-05 - accuracy: 1.0000
# Epoch 79/100
# 158/158 [==============================] - 1s 9ms/step - loss: 7.1449e-06 - accuracy: 1.0000
# Epoch 80/100
# 158/158 [==============================] - 1s 9ms/step - loss: 2.7872e-05 - accuracy: 1.0000
# Epoch 81/100
# 158/158 [==============================] - 2s 10ms/step - loss: 1.8607e-05 - accuracy: 1.0000
# Epoch 82/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0531 - accuracy: 0.9902
# Epoch 83/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0680 - accuracy: 0.9829
# Epoch 84/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0517 - accuracy: 0.9832
# Epoch 85/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0316 - accuracy: 0.9933
# Epoch 86/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0091 - accuracy: 0.9965
# Epoch 87/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0113 - accuracy: 0.9971
# Epoch 88/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 89/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0109 - accuracy: 0.9975
# Epoch 90/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0024 - accuracy: 0.9994
# Epoch 91/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0075 - accuracy: 0.9971
# Epoch 92/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 93/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0189 - accuracy: 0.9949
# Epoch 94/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 0.9981
# Epoch 95/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 96/100
# 158/158 [==============================] - 1s 9ms/step - loss: 7.8434e-04 - accuracy: 0.9994
# Epoch 97/100
# 158/158 [==============================] - 1s 9ms/step - loss: 6.7842e-04 - accuracy: 0.9997
# Epoch 98/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 99/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0059 - accuracy: 0.9981
# Epoch 100/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0280 - accuracy: 0.9905
# 20/20 - 0s - loss: 0.3794 - accuracy: 0.8705
# [[340  82]
#  [  0 211]]
#
#  [422 211]
# sensitivity :  1.0
# specificity :  0.8056872037914692
# frr :  0.0
# far :  0.1943127962085308
# (3156, 480, 2)
# (633, 480, 2)
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_63 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_63 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_64 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_65 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_65 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_64 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_65 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 11  #
# ##########
# Epoch 1/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.2108 - accuracy: 0.9208
# Epoch 2/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1439 - accuracy: 0.9477
# Epoch 3/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1345 - accuracy: 0.9503
# Epoch 4/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1357 - accuracy: 0.9537
# Epoch 5/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1202 - accuracy: 0.9579
# Epoch 6/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1176 - accuracy: 0.9575
# Epoch 7/100
# 158/158 [==============================] - 2s 9ms/step - loss: 0.1153 - accuracy: 0.9591
# Epoch 8/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1089 - accuracy: 0.9610
# Epoch 9/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1077 - accuracy: 0.9645
# Epoch 10/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0986 - accuracy: 0.9651
# Epoch 11/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0995 - accuracy: 0.9655
# Epoch 12/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1071 - accuracy: 0.9613
# Epoch 13/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0931 - accuracy: 0.9674
# Epoch 14/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0882 - accuracy: 0.9677
# Epoch 15/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0990 - accuracy: 0.9689
# Epoch 16/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0847 - accuracy: 0.9680
# Epoch 17/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0791 - accuracy: 0.9712
# Epoch 18/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0742 - accuracy: 0.9759
# Epoch 19/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0858 - accuracy: 0.9664
# Epoch 20/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0594 - accuracy: 0.9797
# Epoch 21/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0612 - accuracy: 0.9772
# Epoch 22/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0671 - accuracy: 0.9750
# Epoch 23/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0489 - accuracy: 0.9826
# Epoch 24/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0577 - accuracy: 0.9800
# Epoch 25/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0701 - accuracy: 0.9781
# Epoch 26/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0516 - accuracy: 0.9804
# Epoch 27/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0395 - accuracy: 0.9842
# Epoch 28/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0317 - accuracy: 0.9880
# Epoch 29/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0391 - accuracy: 0.9867
# Epoch 30/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0763 - accuracy: 0.9750
# Epoch 31/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0482 - accuracy: 0.9816
# Epoch 32/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0307 - accuracy: 0.9902
# Epoch 33/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0637 - accuracy: 0.9740
# Epoch 34/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0445 - accuracy: 0.9838
# Epoch 35/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0278 - accuracy: 0.9895
# Epoch 36/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0230 - accuracy: 0.9918
# Epoch 37/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0303 - accuracy: 0.9899
# Epoch 38/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0150 - accuracy: 0.9943
# Epoch 39/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0239 - accuracy: 0.9892
# Epoch 40/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0392 - accuracy: 0.9867
# Epoch 41/100
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0140 - accuracy: 0.9959
# Epoch 42/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0319 - accuracy: 0.9899
# Epoch 43/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0286 - accuracy: 0.9902
# Epoch 44/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0260 - accuracy: 0.9905
# Epoch 45/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0301 - accuracy: 0.9905
# Epoch 46/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0133 - accuracy: 0.9959
# Epoch 47/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0237 - accuracy: 0.9911
# Epoch 48/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0245 - accuracy: 0.9908
# Epoch 49/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0063 - accuracy: 0.9981
# Epoch 50/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0191 - accuracy: 0.9933
# Epoch 51/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0213 - accuracy: 0.9924
# Epoch 52/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0142 - accuracy: 0.9933
# Epoch 53/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0134 - accuracy: 0.9959
# Epoch 54/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0248 - accuracy: 0.9899
# Epoch 55/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0250 - accuracy: 0.9921
# Epoch 56/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0312 - accuracy: 0.9911
# Epoch 57/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0131 - accuracy: 0.9956
# Epoch 58/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0403 - accuracy: 0.9851
# Epoch 59/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0119 - accuracy: 0.9946
# Epoch 60/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0330 - accuracy: 0.9918
# Epoch 61/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0174 - accuracy: 0.9943
# Epoch 62/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0102 - accuracy: 0.9965
# Epoch 63/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0448 - accuracy: 0.9851
# Epoch 64/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0293 - accuracy: 0.9905
# Epoch 65/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0175 - accuracy: 0.9949
# Epoch 66/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0241 - accuracy: 0.9921
# Epoch 67/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0157 - accuracy: 0.9940
# Epoch 68/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0195 - accuracy: 0.9949
# Epoch 69/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0146 - accuracy: 0.9956
# Epoch 70/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0174 - accuracy: 0.9946
# Epoch 71/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0295 - accuracy: 0.9895
# Epoch 72/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0153 - accuracy: 0.9962
# Epoch 73/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0197 - accuracy: 0.9911
# Epoch 74/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0586 - accuracy: 0.9819
# Epoch 75/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0290 - accuracy: 0.9902
# Epoch 76/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0182 - accuracy: 0.9937
# Epoch 77/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0330 - accuracy: 0.9889
# Epoch 78/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0143 - accuracy: 0.9959
# Epoch 79/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0136 - accuracy: 0.9952
# Epoch 80/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 81/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 82/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 83/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0222 - accuracy: 0.9930
# Epoch 84/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0086 - accuracy: 0.9981
# Epoch 85/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0329 - accuracy: 0.9914
# Epoch 86/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0237 - accuracy: 0.9924
# Epoch 87/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0215 - accuracy: 0.9937
# Epoch 88/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0244 - accuracy: 0.9918
# Epoch 89/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0284 - accuracy: 0.9902
# Epoch 90/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0303 - accuracy: 0.9899
# Epoch 91/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0088 - accuracy: 0.9965
# Epoch 92/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0254 - accuracy: 0.9908
# Epoch 93/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 94/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0195 - accuracy: 0.9940
# Epoch 95/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0264 - accuracy: 0.9930
# Epoch 96/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0170 - accuracy: 0.9946
# Epoch 97/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0186 - accuracy: 0.9940
# Epoch 98/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0098 - accuracy: 0.9956
# Epoch 99/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0176 - accuracy: 0.9918
# Epoch 100/100
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0147 - accuracy: 0.9952
# 20/20 - 0s - loss: 2.1485 - accuracy: 0.7014
# [[240 182]
#  [  7 204]]
#
#  [422 211]
# sensitivity :  0.966824644549763
# specificity :  0.5687203791469194
# frr :  0.03317535545023697
# far :  0.4312796208530806
# average_accuracy
# 0.7414907325397838
# average_sensitivity
# 0.9586385178802241
# average_specificity
# 0.6329168461869883
# average_frr
# 0.04136148211977596
# average_far
# 0.36708315381301165
