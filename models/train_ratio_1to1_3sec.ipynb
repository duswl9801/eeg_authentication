# %%
import scipy.io
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
from tensorflow.keras.callbacks import  EarlyStopping
import random

# 기존 train 데이터 불러오기
# [11, 505000, 2]
train_sub_data = scipy.io.loadmat('../datas/160hz/train_5day_160hz.mat', squeeze_me=True)['data']

# 퍼블릭 데이터 불러오기
# [109, 9600, 2]
public_data = scipy.io.loadmat('../datas/160hz/Motor_Imagery.mat', squeeze_me=True)['data']

# 기존 test 데이터 불러오기
# [11, 101402, 2]
test_sub_data = scipy.io.loadmat('../datas/160hz/test_6day_160hz(2).mat', squeeze_me=True)['data']

# # 데이터를 480(= 160*3) 크기로 사용할 수 있도록 그 배수로 전체 데이터 잘라줌
data_cut_size = 504960 # 480*1052 = 504960
public_cut_size = 9600 # 480*20 = 9600
test_cut_size = 101280 # 480*211 = 101280

# 트레인 sub 수
train_sub_cnt = train_sub_data.shape[0]
# 퍼블릭 데이터 sub 수
public_sub_cnt = public_data.shape[0]
# test 데이터 sub 수
test_sub_cnt = test_sub_data.shape[0]

sub_cnt = train_sub_cnt + public_sub_cnt

train_sub_cut = train_sub_data[:, 0:data_cut_size, :]
public_data_cut = public_data[:, 0:public_cut_size, :]
test_sub_cut = test_sub_data[:, 0:test_cut_size, :]

print(train_sub_cut.shape)
print(test_sub_cut.shape)
print(public_data_cut.shape)

# 데이터를 스케일링 하기 위해 2D로 reshape
train_sub_2D = train_sub_cut.reshape(-1, 1)
public_data_2D = public_data_cut.reshape(-1, 1)
test_2D = test_sub_cut.reshape(-1, 1)

# 데이터를 StandardScaler로 스케일링
# 데이터의 형태가 많이 다르기 때문에 따로 스케일링 해줘야함
SDscaler = StandardScaler()
SDscaler.fit(train_sub_2D)
train_scaled = SDscaler.transform(train_sub_2D)
test_scaled = SDscaler.transform(test_2D)

#SDscaler_public = StandardScaler()
#SDscaler_public.fit(public_data_2D)
public_scaled = SDscaler.transform(public_data_2D)

# # 스케일링 후 train_data 합쳐줌
# train_data = np.append(origin_data_scaled, public_data_scaled)
# train_data = train_data.reshape(-1, 1)

# 데이터 크기를 480로 맞춰줌
# 5554560/480 = 115,72
data_size = 480
train_sub_size = 1052
public_sub_size = 20
test_sub_size = 211

train_data = train_scaled.reshape(train_sub_cnt * train_sub_size, data_size, 2)
public_data = public_scaled.reshape(public_sub_cnt * public_sub_size, data_size, 2)
test_data = test_scaled.reshape(test_sub_cnt * test_sub_size, data_size, 2)

print(train_data.shape)
print(public_data.shape)
print(test_data.shape)

#test data를 sub:other=1:1로 만들기 위해서 각 sub 추출
test_data_each = []
for i in range(test_sub_cnt):
    test_data_each.insert(i, test_data[i*test_sub_size:(i+1)*test_sub_size, :, :])
# print(test_data_each)

#train data를 sub:other=1:1로 만들기 위해서 각 sub 추출
train_data_each = []
for i in range(train_sub_cnt):
    train_data_each.insert(i, train_data[i*train_sub_size:(i+1)*train_sub_size, :, :])
    
public_data_each = []
for i in range(public_sub_cnt):
    public_data_each.insert(i, public_data[i*public_sub_size:(i+1)*public_sub_size, :, :])
# Out:
# (11, 504960, 2)
# (11, 101280, 2)
# (109, 9600, 2)
# (11572, 480, 2)
# (2180, 480, 2)
# (2321, 480, 2)

# %%
# 평가 지표
test_pre_all = []
conf_mat_all = []
test_loss_all = []
test_acc_all = []
test_sen_all = []
test_spe_all = []
FRR_all = []
FAR_all = []

# %%
# 각 sub 마다 모델 학습

# train data를 sub:other = 1:1로 만들기
# 데이터 크기 504960 : 504960
# 3초 덩어리 개수 1052 : 1052
# 8 * 19 + 9 * 100 = 1052

# test data를 sub:other = 1:1로 만들기
# 데이터 크기 101280 : 101280
# 3초 덩어리 개수 211 : 211
# 21 * 9 + 22 * 1 = 211

for i in range(train_sub_cnt):
    cnt = 0
    train_data_n = train_data_each[i]
    test_data_n = test_data_each[i]
    
    for j in range(sub_cnt):
        if j != i and cnt < 19:
            cnt = cnt + 1
            if j < 11:
                train_data_n = np.append(train_data_n, np.array(random.sample(list(train_data_each[j]), 8)), axis = 0)
            else:
                train_data_n = np.append(train_data_n, np.array(random.sample(list(public_data_each[j-11]), 8)), axis = 0)
        elif j != i and cnt >= 19:
            train_data_n = np.append(train_data_n, np.array(random.sample(list(public_data_each[j-11]), 9)), axis = 0)
    
    cnt = 0
    
    for j in range(test_sub_cnt):
        if j != i and cnt < 9:
            cnt = cnt + 1
            test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 21)), axis = 0)
        elif j != i and cnt >= 9:
            test_data_n = np.append(test_data_n, np.array(random.sample(list(test_data_each[j]), 22)), axis = 0)
            
    print(train_data_n.shape)
    print(test_data_n.shape)
    
    train_label = np.zeros(2104)
    test_label = np.zeros(422)
    
    for j in range(len(train_label)):
        if (j < train_sub_size):
            train_label[j] = 1
            
    for j in range(len(test_label)):
        if (j < test_sub_size):
            test_label[j] = 1
            
    ################################################################
    # 모델 구성하기                                                #
    # 이진 분류이기 때문에 0~1 사이의 값을 나타내는 출력뉴런 1개   #
    ################################################################

    # Cnn 층
    inputs = tf.keras.Input(shape = (480, 2))

    layers = tf.keras.layers.Conv1D(filters = 16, kernel_size = 3, strides = 1, padding = 'same', activation  = 'relu')(inputs)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    layers = tf.keras.layers.Conv1D(filters = 32, kernel_size = 3, strides = 1, padding = 'same', activation  = 'relu')(layers)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    layers = tf.keras.layers.Conv1D(filters = 64, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu')(layers)
    layers = tf.keras.layers.MaxPool1D(3)(layers)

    # LSTM 층
    layers = tf.keras.layers.LSTM(64)(layers)

    # Dense 층
    layers = tf.keras.layers.Dropout(0.3)(layers)
    layers = tf.keras.layers.Dense(128, activation='relu')(layers)
    # layers = tf.keras.layers.Dropout(0.01)(layers)
    layers = tf.keras.layers.Dense(64, activation='relu')(layers)
    # layers = tf.keras.layers.Dropout(0.05)(layers)
    layers = tf.keras.layers.Dense(1, activation='sigmoid')(layers)

    model = tf.keras.models.Model(inputs = inputs, outputs = layers)
    model.compile(loss= 'binary_crossentropy', optimizer= tf.keras.optimizers.Adam(0.005), metrics=['accuracy'])
    model.summary()
    
    early_stopping = tf.keras.callbacks.EarlyStopping(patience= 20)
    
#     # train 데이터를 train과 validation으로 분배
#     # validation 데이터를 여러 sub에서 가져갈 수 있도록 shuffle
#     x_train, x_val, y_train, y_val = train_test_split(train_data, train_label, test_size=0.1, shuffle=True, random_state=1)

    print('##########')
    print('# sub', i+1, ' #')
    print('##########')

    # 모델 돌리기
#     hist = model.fit(x_train, y_train, batch_size=40, epochs=200, validation_data=(x_val, y_val), verbose=1, callbacks= [early_stopping])
    hist = model.fit(train_data_n, train_label, batch_size=20, epochs=100, verbose=1)
    
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()
    
    loss_ax.plot(hist.history['loss'], 'y', label = 'train loss')
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    loss_ax.legend(loc='upper left')
    
    
    acc_ax.plot(hist.history['accuracy'], 'b', label = 'train acc')
    acc_ax.set_ylabel('acc')
    acc_ax.legend(loc='upper left')
    
    plt.show()
    
    # save model
    model.save('Sub_Model_' + str(i + 1) + '.h5')
    
    test_loss, test_acc = model.evaluate(test_data_n, test_label, verbose= 2)
    test_pred = model.predict(test_data_n)
    
    test_loss_all.append(test_loss)
    test_acc_all.append(test_acc)
    
    # 확률이 0.5이상이면 자신(1), 작으면 타인(0)
    for i in range(len(test_pred)):
        if(0.5 <= test_pred[i]):
            test_pred[i] = 1

        else:
            test_pred[i] = 0
            
            
    test_pre_all.append(test_pred)
    
    # confusion matrix 생성
    conf_matrix = confusion_matrix(test_label, test_pred)
    
    #############################################################
    #       conf_matrix[0][0] = TN      conf_matrix[0][1] = FP  #
    #       conf_matrix[1][0] = FN      conf_matrix[1][1] = TP  #
    #############################################################

    print(conf_matrix)
    conf_mat_all.append(conf_matrix)

    # sum 이용 각 행 더하기
    row = conf_matrix.sum(axis=1)
    print('\n', row)

    # row[0] = spec의 분모, row[1] = sens의 분모

    test_sensitivity = conf_matrix[1][1] / row[1]
    test_specificity = conf_matrix[0][0] / row[0]

    print('sensitivity : ', test_sensitivity)
    print('specificity : ', test_specificity) 
    
    test_sen_all.append(test_sensitivity)
    test_spe_all.append(test_specificity)
    
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111)

    cax = ax.matshow(conf_matrix)

    fig.colorbar(cax)

    for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):
        plt.text(j, i, conf_matrix[i, j], color="white")

    plt.title('CNN+LSTM model')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')

    plt.show()
    
print('average_accuracy')
print(np.mean(test_acc_all))
print('average_sensitivity')
print(np.mean(test_sen_all))
print('average_specificity')
print(np.mean(test_spe_all))
# Out:
# (2104, 480, 2)
# (422, 480, 2)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 160, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 53, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 17, 64)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                33024
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 1  #
# ##########
# Epoch 1/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.2146 - accuracy: 0.9278
# Epoch 2/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1642 - accuracy: 0.9501
# Epoch 3/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1492 - accuracy: 0.9567
# Epoch 4/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1020 - accuracy: 0.9606
# Epoch 5/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1367 - accuracy: 0.9558
# Epoch 6/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1136 - accuracy: 0.9601
# Epoch 7/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1032 - accuracy: 0.9606
# Epoch 8/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0975 - accuracy: 0.9596
# Epoch 9/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1094 - accuracy: 0.9653
# Epoch 10/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0986 - accuracy: 0.9620
# Epoch 11/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0879 - accuracy: 0.9634
# Epoch 12/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0914 - accuracy: 0.9705
# Epoch 13/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1035 - accuracy: 0.9629
# Epoch 14/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0829 - accuracy: 0.9691
# Epoch 15/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0738 - accuracy: 0.9720
# Epoch 16/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0789 - accuracy: 0.9686
# Epoch 17/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0725 - accuracy: 0.9724
# Epoch 18/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1325 - accuracy: 0.9615
# Epoch 19/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1206 - accuracy: 0.9591
# Epoch 20/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0953 - accuracy: 0.9639
# Epoch 21/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1111 - accuracy: 0.9620
# Epoch 22/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0895 - accuracy: 0.9663
# Epoch 23/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0806 - accuracy: 0.9672
# Epoch 24/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0890 - accuracy: 0.9615
# Epoch 25/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0848 - accuracy: 0.9606
# Epoch 26/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0633 - accuracy: 0.9748
# Epoch 27/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0670 - accuracy: 0.9758
# Epoch 28/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0671 - accuracy: 0.9777
# Epoch 29/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0608 - accuracy: 0.9734
# Epoch 30/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0490 - accuracy: 0.9834
# Epoch 31/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0521 - accuracy: 0.9777
# Epoch 32/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0591 - accuracy: 0.9772
# Epoch 33/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0405 - accuracy: 0.9876
# Epoch 34/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0484 - accuracy: 0.9796
# Epoch 35/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0392 - accuracy: 0.9895
# Epoch 36/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0299 - accuracy: 0.9872
# Epoch 37/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0232 - accuracy: 0.9910
# Epoch 38/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0138 - accuracy: 0.9967
# Epoch 39/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0443 - accuracy: 0.9862
# Epoch 40/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0522 - accuracy: 0.9824
# Epoch 41/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0515 - accuracy: 0.9829
# Epoch 42/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0386 - accuracy: 0.9867
# Epoch 43/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0369 - accuracy: 0.9857
# Epoch 44/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0695 - accuracy: 0.9791
# Epoch 45/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0374 - accuracy: 0.9857
# Epoch 46/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0494 - accuracy: 0.9805
# Epoch 47/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0302 - accuracy: 0.9919
# Epoch 48/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0302 - accuracy: 0.9914
# Epoch 49/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0304 - accuracy: 0.9891
# Epoch 50/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0123 - accuracy: 0.9957
# Epoch 51/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0095 - accuracy: 0.9971
# Epoch 52/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0292 - accuracy: 0.9886
# Epoch 53/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0306 - accuracy: 0.9886
# Epoch 54/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0149 - accuracy: 0.9962
# Epoch 55/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0179 - accuracy: 0.9948
# Epoch 56/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0268 - accuracy: 0.9910
# Epoch 57/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0459 - accuracy: 0.9862
# Epoch 58/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0109 - accuracy: 0.9952
# Epoch 59/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0098 - accuracy: 0.9967
# Epoch 60/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0107 - accuracy: 0.9948
# Epoch 61/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0348 - accuracy: 0.9905
# Epoch 62/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0392 - accuracy: 0.9848
# Epoch 63/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0284 - accuracy: 0.9895
# Epoch 64/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0139 - accuracy: 0.9952
# Epoch 65/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0417 - accuracy: 0.9857
# Epoch 66/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0157 - accuracy: 0.9938
# Epoch 67/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0093 - accuracy: 0.9962
# Epoch 68/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0483 - accuracy: 0.9876
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0161 - accuracy: 0.9933
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0303 - accuracy: 0.9895
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0107 - accuracy: 0.9957
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0434 - accuracy: 0.9829
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0323 - accuracy: 0.9867
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0447 - accuracy: 0.9857
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0230 - accuracy: 0.9933
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9957
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0072 - accuracy: 0.9976
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0093 - accuracy: 0.9976
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0299 - accuracy: 0.9910
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0440 - accuracy: 0.9881
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0586 - accuracy: 0.9848
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1286 - accuracy: 0.9582
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0723 - accuracy: 0.9748
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0509 - accuracy: 0.9838
# Epoch 85/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0263 - accuracy: 0.9895
# Epoch 86/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0200 - accuracy: 0.9933
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0245 - accuracy: 0.9914
# Epoch 88/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9976
# Epoch 89/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0207 - accuracy: 0.9919
# Epoch 90/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0254 - accuracy: 0.9919
# Epoch 91/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0187 - accuracy: 0.9948
# Epoch 92/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0041 - accuracy: 0.9990
# Epoch 93/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 0.9962
# Epoch 94/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0249 - accuracy: 0.9905
# Epoch 95/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0158 - accuracy: 0.9971
# Epoch 96/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0201 - accuracy: 0.9933
# Epoch 97/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 98/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 99/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 100/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0014 - accuracy: 0.9995
# 14/14 - 0s - loss: 1.9584 - accuracy: 0.7393
# [[105 106]
#  [  4 207]]
#
#  [211 211]
# sensitivity :  0.981042654028436
# specificity :  0.4976303317535545
# (2104, 480, 2)
# (422, 480, 2)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 160, 16)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 53, 32)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 17, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 2  #
# ##########
# Epoch 1/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.2123 - accuracy: 0.9325
# Epoch 2/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1681 - accuracy: 0.9520
# Epoch 3/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1320 - accuracy: 0.9601
# Epoch 4/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1165 - accuracy: 0.9596
# Epoch 5/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1234 - accuracy: 0.9620
# Epoch 6/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1195 - accuracy: 0.9572
# Epoch 7/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1072 - accuracy: 0.9601
# Epoch 8/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1575 - accuracy: 0.9567
# Epoch 9/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1196 - accuracy: 0.9601
# Epoch 10/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0936 - accuracy: 0.9682
# Epoch 11/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0999 - accuracy: 0.9710
# Epoch 12/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0976 - accuracy: 0.9710
# Epoch 13/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0933 - accuracy: 0.9748
# Epoch 14/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1059 - accuracy: 0.9648
# Epoch 15/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0882 - accuracy: 0.9729
# Epoch 16/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0801 - accuracy: 0.9772
# Epoch 17/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0720 - accuracy: 0.9720
# Epoch 18/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0611 - accuracy: 0.9805
# Epoch 19/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0651 - accuracy: 0.9786
# Epoch 20/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0621 - accuracy: 0.9772
# Epoch 21/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0660 - accuracy: 0.9810
# Epoch 22/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0528 - accuracy: 0.9800
# Epoch 23/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0612 - accuracy: 0.9791
# Epoch 24/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0656 - accuracy: 0.9810
# Epoch 25/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0610 - accuracy: 0.9772
# Epoch 26/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0351 - accuracy: 0.9895
# Epoch 27/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0415 - accuracy: 0.9872
# Epoch 28/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0418 - accuracy: 0.9872
# Epoch 29/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0394 - accuracy: 0.9815
# Epoch 30/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0299 - accuracy: 0.9905
# Epoch 31/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0164 - accuracy: 0.9957
# Epoch 32/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0653 - accuracy: 0.9762
# Epoch 33/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0593 - accuracy: 0.9791
# Epoch 34/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0388 - accuracy: 0.9867
# Epoch 35/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0203 - accuracy: 0.9933
# Epoch 36/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0139 - accuracy: 0.9957
# Epoch 37/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0535 - accuracy: 0.9829
# Epoch 38/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0487 - accuracy: 0.9853
# Epoch 39/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0259 - accuracy: 0.9924
# Epoch 40/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0314 - accuracy: 0.9910
# Epoch 41/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0497 - accuracy: 0.9867
# Epoch 42/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0199 - accuracy: 0.9943
# Epoch 43/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0286 - accuracy: 0.9919
# Epoch 44/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0232 - accuracy: 0.9929
# Epoch 45/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0355 - accuracy: 0.9891
# Epoch 46/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0305 - accuracy: 0.9900
# Epoch 47/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0430 - accuracy: 0.9848
# Epoch 48/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0220 - accuracy: 0.9929
# Epoch 49/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0132 - accuracy: 0.9943
# Epoch 50/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0055 - accuracy: 0.9990
# Epoch 51/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 52/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9976
# Epoch 53/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0495 - accuracy: 0.9857
# Epoch 54/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0246 - accuracy: 0.9929
# Epoch 55/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0287 - accuracy: 0.9895
# Epoch 56/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0086 - accuracy: 0.9976
# Epoch 57/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0153 - accuracy: 0.9933
# Epoch 58/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0078 - accuracy: 0.9976
# Epoch 59/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0095 - accuracy: 0.9967
# Epoch 60/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0076 - accuracy: 0.9976
# Epoch 61/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0023 - accuracy: 0.9990
# Epoch 62/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0218 - accuracy: 0.9957
# Epoch 63/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0408 - accuracy: 0.9862
# Epoch 64/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0270 - accuracy: 0.9933
# Epoch 65/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0311 - accuracy: 0.9895
# Epoch 66/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0197 - accuracy: 0.9938
# Epoch 67/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 68/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0034 - accuracy: 0.9981
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0358 - accuracy: 0.9905
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 0.9971
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0106 - accuracy: 0.9957
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0392 - accuracy: 0.9924
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0377 - accuracy: 0.9857
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.9938
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0228 - accuracy: 0.9933
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0114 - accuracy: 0.9967
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0253 - accuracy: 0.9952
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0157 - accuracy: 0.9957
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0122 - accuracy: 0.9962
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 85/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 86/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0135 - accuracy: 0.9957
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0321 - accuracy: 0.9919
# Epoch 88/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0167 - accuracy: 0.9967
# Epoch 89/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0129 - accuracy: 0.9967
# Epoch 90/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0118 - accuracy: 0.9971
# Epoch 91/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0023 - accuracy: 0.9990
# Epoch 92/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0114 - accuracy: 0.9971
# Epoch 93/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0018 - accuracy: 0.9990
# Epoch 94/100
# 106/106 [==============================] - 1s 9ms/step - loss: 5.1984e-04 - accuracy: 1.0000
# Epoch 95/100
# 106/106 [==============================] - 1s 9ms/step - loss: 7.1086e-05 - accuracy: 1.0000
# Epoch 96/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0510 - accuracy: 0.9843
# Epoch 97/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0400 - accuracy: 0.9876
# Epoch 98/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0368 - accuracy: 0.9886
# Epoch 99/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0468 - accuracy: 0.9853
# Epoch 100/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0282 - accuracy: 0.9886
# 14/14 - 0s - loss: 1.3367 - accuracy: 0.7275
# [[ 99 112]
#  [  3 208]]
#
#  [211 211]
# sensitivity :  0.985781990521327
# specificity :  0.46919431279620855
# (2104, 480, 2)
# (422, 480, 2)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 160, 16)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 53, 32)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 17, 64)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 3  #
# ##########
# Epoch 1/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.2189 - accuracy: 0.9230
# Epoch 2/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1591 - accuracy: 0.9544
# Epoch 3/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1140 - accuracy: 0.9691
# Epoch 4/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1221 - accuracy: 0.9644
# Epoch 5/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1079 - accuracy: 0.9691
# Epoch 6/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0989 - accuracy: 0.9705
# Epoch 7/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1691 - accuracy: 0.9425
# Epoch 8/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1076 - accuracy: 0.9696
# Epoch 9/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1066 - accuracy: 0.9724
# Epoch 10/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0910 - accuracy: 0.9739
# Epoch 11/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0792 - accuracy: 0.9758
# Epoch 12/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0861 - accuracy: 0.9753
# Epoch 13/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0794 - accuracy: 0.9739
# Epoch 14/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0746 - accuracy: 0.9796
# Epoch 15/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0835 - accuracy: 0.9767
# Epoch 16/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0680 - accuracy: 0.9781
# Epoch 17/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0750 - accuracy: 0.9791
# Epoch 18/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0835 - accuracy: 0.9796
# Epoch 19/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0663 - accuracy: 0.9777
# Epoch 20/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0841 - accuracy: 0.9777
# Epoch 21/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0721 - accuracy: 0.9786
# Epoch 22/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0637 - accuracy: 0.9791
# Epoch 23/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0675 - accuracy: 0.9800
# Epoch 24/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0636 - accuracy: 0.9777
# Epoch 25/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0563 - accuracy: 0.9834
# Epoch 26/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0602 - accuracy: 0.9796
# Epoch 27/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0749 - accuracy: 0.9786
# Epoch 28/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0481 - accuracy: 0.9848
# Epoch 29/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0649 - accuracy: 0.9834
# Epoch 30/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0488 - accuracy: 0.9843
# Epoch 31/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0394 - accuracy: 0.9886
# Epoch 32/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0463 - accuracy: 0.9824
# Epoch 33/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0320 - accuracy: 0.9895
# Epoch 34/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0447 - accuracy: 0.9834
# Epoch 35/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0592 - accuracy: 0.9824
# Epoch 36/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0270 - accuracy: 0.9900
# Epoch 37/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0264 - accuracy: 0.9933
# Epoch 38/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0338 - accuracy: 0.9881
# Epoch 39/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0325 - accuracy: 0.9876
# Epoch 40/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0175 - accuracy: 0.9943
# Epoch 41/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0177 - accuracy: 0.9948
# Epoch 42/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0474 - accuracy: 0.9815
# Epoch 43/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0218 - accuracy: 0.9929
# Epoch 44/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.9943
# Epoch 45/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0358 - accuracy: 0.9891
# Epoch 46/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0329 - accuracy: 0.9881
# Epoch 47/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0160 - accuracy: 0.9943
# Epoch 48/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0252 - accuracy: 0.9910
# Epoch 49/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0102 - accuracy: 0.9981
# Epoch 50/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0070 - accuracy: 0.9981
# Epoch 51/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0148 - accuracy: 0.9943
# Epoch 52/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0327 - accuracy: 0.9933
# Epoch 53/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0669 - accuracy: 0.9772
# Epoch 54/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0260 - accuracy: 0.9933
# Epoch 55/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0101 - accuracy: 0.9967
# Epoch 56/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0203 - accuracy: 0.9943
# Epoch 57/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0319 - accuracy: 0.9900
# Epoch 58/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0059 - accuracy: 0.9981
# Epoch 59/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.7796e-04 - accuracy: 1.0000
# Epoch 60/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0701 - accuracy: 0.9819
# Epoch 61/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0784 - accuracy: 0.9796
# Epoch 62/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0222 - accuracy: 0.9938
# Epoch 63/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0326 - accuracy: 0.9895
# Epoch 64/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.9933
# Epoch 65/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0162 - accuracy: 0.9943
# Epoch 66/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0225 - accuracy: 0.9919
# Epoch 67/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0310 - accuracy: 0.9881
# Epoch 68/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0120 - accuracy: 0.9971
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0031 - accuracy: 0.9986
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.9287e-04 - accuracy: 1.0000
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.6303e-04 - accuracy: 1.0000
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 7.0442e-04 - accuracy: 0.9995
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0207 - accuracy: 0.9948
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.5674e-04 - accuracy: 1.0000
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0203 - accuracy: 0.9962
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0225 - accuracy: 0.9924
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0314 - accuracy: 0.9914
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0088 - accuracy: 0.9981
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9976
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0107 - accuracy: 0.9971
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9933
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0126 - accuracy: 0.9957
# Epoch 85/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 86/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0307 - accuracy: 0.9924
# Epoch 88/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0153 - accuracy: 0.9967
# Epoch 89/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0083 - accuracy: 0.9962
# Epoch 90/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0364 - accuracy: 0.9853
# Epoch 91/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0346 - accuracy: 0.9900
# Epoch 92/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 0.9967
# Epoch 93/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0074 - accuracy: 0.9962
# Epoch 94/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0257 - accuracy: 0.9948
# Epoch 95/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0338 - accuracy: 0.9905
# Epoch 96/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0039 - accuracy: 0.9995
# Epoch 97/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0128 - accuracy: 0.9971
# Epoch 98/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0223 - accuracy: 0.9914
# Epoch 99/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0129 - accuracy: 0.9952
# Epoch 100/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0188 - accuracy: 0.9962
# 14/14 - 0s - loss: 0.6493 - accuracy: 0.7938
# [[126  85]
#  [  2 209]]
#
#  [211 211]
# sensitivity :  0.990521327014218
# specificity :  0.5971563981042654
# (2104, 480, 2)
# (422, 480, 2)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 160, 16)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 4  #
# ##########
# Epoch 1/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.2075 - accuracy: 0.9240
# Epoch 2/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1511 - accuracy: 0.9544
# Epoch 3/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1392 - accuracy: 0.9596
# Epoch 4/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1310 - accuracy: 0.9582
# Epoch 5/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1264 - accuracy: 0.9629
# Epoch 6/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1174 - accuracy: 0.9658
# Epoch 7/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1219 - accuracy: 0.9667
# Epoch 8/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1041 - accuracy: 0.9686
# Epoch 9/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1115 - accuracy: 0.9682
# Epoch 10/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1219 - accuracy: 0.9658
# Epoch 11/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1024 - accuracy: 0.9696
# Epoch 12/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0902 - accuracy: 0.9701
# Epoch 13/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0883 - accuracy: 0.9724
# Epoch 14/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1252 - accuracy: 0.9596
# Epoch 15/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1103 - accuracy: 0.9667
# Epoch 16/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0882 - accuracy: 0.9715
# Epoch 17/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0782 - accuracy: 0.9734
# Epoch 18/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0674 - accuracy: 0.9772
# Epoch 19/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1135 - accuracy: 0.9653
# Epoch 20/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0829 - accuracy: 0.9748
# Epoch 21/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0703 - accuracy: 0.9762
# Epoch 22/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.0641 - accuracy: 0.9753
# Epoch 23/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0599 - accuracy: 0.9810
# Epoch 24/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0494 - accuracy: 0.9815
# Epoch 25/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0403 - accuracy: 0.9819
# Epoch 26/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0579 - accuracy: 0.9786
# Epoch 27/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0301 - accuracy: 0.9891
# Epoch 28/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0567 - accuracy: 0.9838
# Epoch 29/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0435 - accuracy: 0.9853
# Epoch 30/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0303 - accuracy: 0.9891
# Epoch 31/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0278 - accuracy: 0.9905
# Epoch 32/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0342 - accuracy: 0.9910
# Epoch 33/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0499 - accuracy: 0.9843
# Epoch 34/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0384 - accuracy: 0.9881
# Epoch 35/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0402 - accuracy: 0.9900
# Epoch 36/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0412 - accuracy: 0.9867
# Epoch 37/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0434 - accuracy: 0.9843
# Epoch 38/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0241 - accuracy: 0.9943
# Epoch 39/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0153 - accuracy: 0.9967
# Epoch 40/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0324 - accuracy: 0.9872
# Epoch 41/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0233 - accuracy: 0.9929
# Epoch 42/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0668 - accuracy: 0.9777
# Epoch 43/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0219 - accuracy: 0.9919
# Epoch 44/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0173 - accuracy: 0.9943
# Epoch 45/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0309 - accuracy: 0.9872
# Epoch 46/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0354 - accuracy: 0.9876
# Epoch 47/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0326 - accuracy: 0.9905
# Epoch 48/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0297 - accuracy: 0.9924
# Epoch 49/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0413 - accuracy: 0.9872
# Epoch 50/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0211 - accuracy: 0.9938
# Epoch 51/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.9952
# Epoch 52/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9924
# Epoch 53/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0395 - accuracy: 0.9876
# Epoch 54/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0207 - accuracy: 0.9924
# Epoch 55/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0350 - accuracy: 0.9853
# Epoch 56/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0207 - accuracy: 0.9929
# Epoch 57/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0274 - accuracy: 0.9910
# Epoch 58/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0275 - accuracy: 0.9905
# Epoch 59/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0296 - accuracy: 0.9891
# Epoch 60/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0148 - accuracy: 0.9948
# Epoch 61/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0439 - accuracy: 0.9867
# Epoch 62/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0336 - accuracy: 0.9867
# Epoch 63/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0157 - accuracy: 0.9938
# Epoch 64/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0134 - accuracy: 0.9952
# Epoch 65/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9957
# Epoch 66/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0300 - accuracy: 0.9895
# Epoch 67/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0130 - accuracy: 0.9957
# Epoch 68/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0111 - accuracy: 0.9971
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0038 - accuracy: 0.9995
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0055 - accuracy: 0.9971
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9976
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.1902e-04 - accuracy: 1.0000
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.1755e-04 - accuracy: 0.9995
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0239 - accuracy: 0.9929
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0405 - accuracy: 0.9819
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0232 - accuracy: 0.9924
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0132 - accuracy: 0.9943
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9976
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0272 - accuracy: 0.9891
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0075 - accuracy: 0.9967
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 5.9957e-04 - accuracy: 1.0000
# Epoch 85/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0253 - accuracy: 0.9933
# Epoch 86/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0369 - accuracy: 0.9891
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0214 - accuracy: 0.9948
# Epoch 88/100
# ...
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0129 - accuracy: 0.9957
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.0560e-04 - accuracy: 1.0000
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 8.3815e-05 - accuracy: 1.0000
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.3399e-04 - accuracy: 1.0000
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 8.9732e-05 - accuracy: 1.0000
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 6.3300e-05 - accuracy: 1.0000
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 3.3303e-05 - accuracy: 1.0000
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.1760e-05 - accuracy: 1.0000
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.4670e-05 - accuracy: 1.0000
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.9871e-05 - accuracy: 1.0000
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.6979e-05 - accuracy: 1.0000
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 3.2063e-05 - accuracy: 1.0000
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.9889e-05 - accuracy: 1.0000
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.3653e-06 - accuracy: 1.0000
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 5.5209e-06 - accuracy: 1.0000
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0613 - accuracy: 0.9876
# Epoch 85/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0647 - accuracy: 0.9834
# Epoch 86/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0140 - accuracy: 0.9948
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.2400e-04 - accuracy: 1.0000
# Epoch 88/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0794 - accuracy: 0.9829
# Epoch 89/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0278 - accuracy: 0.9905
# Epoch 90/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0190 - accuracy: 0.9952
# Epoch 91/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 92/100
# 106/106 [==============================] - 1s 9ms/step - loss: 7.6700e-04 - accuracy: 1.0000
# Epoch 93/100
# 106/106 [==============================] - 1s 9ms/step - loss: 5.0452e-04 - accuracy: 1.0000
# Epoch 94/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0250 - accuracy: 0.9967
# Epoch 95/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0327 - accuracy: 0.9919
# Epoch 96/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0200 - accuracy: 0.9952
# Epoch 97/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0073 - accuracy: 0.9981
# Epoch 98/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0075 - accuracy: 0.9971
# Epoch 99/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 100/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0048 - accuracy: 0.9981
# 14/14 - 0s - loss: 0.2511 - accuracy: 0.9502
# [[192  19]
#  [  2 209]]
#
#  [211 211]
# sensitivity :  0.990521327014218
# specificity :  0.909952606635071
# (2104, 480, 2)
# (422, 480, 2)
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 480, 2)]          0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 480, 16)           112
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 160, 16)           0
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 160, 32)           1568
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 53, 32)            0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 53, 64)            6208
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 57,553
# Trainable params: 57,553
# Non-trainable params: 0
# _________________________________________________________________
# ##########
# # sub 11  #
# ##########
# Epoch 1/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.2133 - accuracy: 0.9316
# Epoch 2/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1695 - accuracy: 0.9525
# Epoch 3/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1663 - accuracy: 0.9510
# Epoch 4/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1306 - accuracy: 0.9591
# Epoch 5/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1235 - accuracy: 0.9629
# Epoch 6/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1318 - accuracy: 0.9606
# Epoch 7/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1251 - accuracy: 0.9606
# Epoch 8/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1274 - accuracy: 0.9620
# Epoch 9/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1218 - accuracy: 0.9639
# Epoch 10/100
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1208 - accuracy: 0.9615
# Epoch 11/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1190 - accuracy: 0.9663
# Epoch 12/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1074 - accuracy: 0.9658
# Epoch 13/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1078 - accuracy: 0.9696
# Epoch 14/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1172 - accuracy: 0.9615
# Epoch 15/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1035 - accuracy: 0.9667
# Epoch 16/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1156 - accuracy: 0.9596
# Epoch 17/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1071 - accuracy: 0.9677
# Epoch 18/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1030 - accuracy: 0.9696
# Epoch 19/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0877 - accuracy: 0.9734
# Epoch 20/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0898 - accuracy: 0.9724
# Epoch 21/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0848 - accuracy: 0.9743
# Epoch 22/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0843 - accuracy: 0.9762
# Epoch 23/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0819 - accuracy: 0.9753
# Epoch 24/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0753 - accuracy: 0.9729
# Epoch 25/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0893 - accuracy: 0.9701
# Epoch 26/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0840 - accuracy: 0.9705
# Epoch 27/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0562 - accuracy: 0.9805
# Epoch 28/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0552 - accuracy: 0.9791
# Epoch 29/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0718 - accuracy: 0.9743
# Epoch 30/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0696 - accuracy: 0.9791
# Epoch 31/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0390 - accuracy: 0.9862
# Epoch 32/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0526 - accuracy: 0.9810
# Epoch 33/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0245 - accuracy: 0.9914
# Epoch 34/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0262 - accuracy: 0.9924
# Epoch 35/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0508 - accuracy: 0.9829
# Epoch 36/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0430 - accuracy: 0.9853
# Epoch 37/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0127 - accuracy: 0.9957
# Epoch 38/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0516 - accuracy: 0.9862
# Epoch 39/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0891 - accuracy: 0.9672
# Epoch 40/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0546 - accuracy: 0.9815
# Epoch 41/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0423 - accuracy: 0.9805
# Epoch 42/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0301 - accuracy: 0.9881
# Epoch 43/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0222 - accuracy: 0.9914
# Epoch 44/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0393 - accuracy: 0.9891
# Epoch 45/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0132 - accuracy: 0.9943
# Epoch 46/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0229 - accuracy: 0.9938
# Epoch 47/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 48/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0105 - accuracy: 0.9962
# Epoch 49/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0089 - accuracy: 0.9981
# Epoch 50/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0148 - accuracy: 0.9938
# Epoch 51/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 52/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0250 - accuracy: 0.9914
# Epoch 53/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0056 - accuracy: 0.9971
# Epoch 54/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0172 - accuracy: 0.9924
# Epoch 55/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0112 - accuracy: 0.9952
# Epoch 56/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0053 - accuracy: 0.9971
# Epoch 57/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0212 - accuracy: 0.9943
# Epoch 58/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0110 - accuracy: 0.9971
# Epoch 59/100
# 106/106 [==============================] - 1s 9ms/step - loss: 5.3031e-04 - accuracy: 1.0000
# Epoch 60/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.6072e-04 - accuracy: 1.0000
# Epoch 61/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.2106e-04 - accuracy: 1.0000
# Epoch 62/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.3467e-05 - accuracy: 1.0000
# Epoch 63/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.0489e-05 - accuracy: 1.0000
# Epoch 64/100
# 106/106 [==============================] - 1s 9ms/step - loss: 8.9911e-05 - accuracy: 1.0000
# Epoch 65/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.5355e-04 - accuracy: 1.0000
# Epoch 66/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.4254e-05 - accuracy: 1.0000
# Epoch 67/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.8679e-05 - accuracy: 1.0000
# Epoch 68/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0167 - accuracy: 0.9981
# Epoch 69/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0899 - accuracy: 0.9686
# Epoch 70/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0747 - accuracy: 0.9682
# Epoch 71/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0380 - accuracy: 0.9867
# Epoch 72/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0259 - accuracy: 0.9910
# Epoch 73/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0140 - accuracy: 0.9981
# Epoch 74/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0591 - accuracy: 0.9805
# Epoch 75/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0223 - accuracy: 0.9910
# Epoch 76/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0256 - accuracy: 0.9943
# Epoch 77/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0216 - accuracy: 0.9933
# Epoch 78/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0261 - accuracy: 0.9919
# Epoch 79/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 80/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0066 - accuracy: 0.9976
# Epoch 81/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0204 - accuracy: 0.9924
# Epoch 82/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0104 - accuracy: 0.9976
# Epoch 83/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0113 - accuracy: 0.9962
# Epoch 84/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0175 - accuracy: 0.9957
# Epoch 85/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0094 - accuracy: 0.9971
# Epoch 86/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 87/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.8674e-04 - accuracy: 1.0000
# Epoch 88/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.4227e-04 - accuracy: 1.0000
# Epoch 89/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 90/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0277 - accuracy: 0.9914
# Epoch 91/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0169 - accuracy: 0.9933
# Epoch 92/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0208 - accuracy: 0.9948
# Epoch 93/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0072 - accuracy: 0.9967
# Epoch 94/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0076 - accuracy: 0.9967
# Epoch 95/100
# 106/106 [==============================] - 1s 9ms/step - loss: 4.4616e-04 - accuracy: 1.0000
# Epoch 96/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 97/100
# 106/106 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 98/100
# 106/106 [==============================] - 1s 9ms/step - loss: 2.9561e-04 - accuracy: 1.0000
# Epoch 99/100
# 106/106 [==============================] - 1s 9ms/step - loss: 9.4038e-04 - accuracy: 0.9995
# Epoch 100/100
# 106/106 [==============================] - 1s 9ms/step - loss: 1.5730e-04 - accuracy: 1.0000
# 14/14 - 0s - loss: 3.3633 - accuracy: 0.6825
# [[ 79 132]
#  [  2 209]]
#
#  [211 211]
# sensitivity :  0.990521327014218
# specificity :  0.3744075829383886
# average_accuracy
# 0.7382593696767633
# average_sensitivity
# 0.984489444205084
# average_specificity
# 0.4920292977165015

# %%
test_precision_all = []
for i in range(len(conf_mat_all)):
    test_precision = conf_mat_all[i][1][1] / (conf_mat_all[i][1][1] + conf_mat_all[i][0][1])
    test_precision_all.append(test_precision)
    
test_pre_all_o = test_pre_all
conf_mat_all_o = conf_mat_all
test_loss_all_o = test_loss_all
test_acc_all_o = test_acc_all
test_sen_all_o = test_sen_all
test_spe_all_o = test_spe_all
test_precision_all_o = test_precision_all

predict = np.array(test_pre_all_o, dtype=np.int8)
print(predict.shape[0])
print(predict.shape[1])
print(predict.shape[2])
predict = predict.reshape(11, 422).T

conf_mat = np.array(conf_mat_all_o)

loss = np.array(test_loss_all_o)

acc = np.array(test_acc_all_o)
sen = np.array(test_sen_all_o)
spe = np.array(test_spe_all_o)
pre = np.array(test_precision_all_o)

import pandas as pd

# Create a Pandas Excel writer
writer = pd.ExcelWriter('Result.xlsx')

# Test_Predict
df_predict = pd.DataFrame([])

# Confusion_Matrix
# conf_mat의 엑셀에서 위치 저장할 변수
conf_row = 1
conf_col = 0

# 포문쓰기
for i in range(test_sub_cnt):
#     columns = list("01")
#     columns = list(zip(['Sub_' + str(i+1)] * 2, columns))
#     columns = pd.MultiIndex.from_tuples(columns)  
    df_conf = pd.DataFrame(conf_mat[i], index=['Other', 'Sub'], columns=[['Sub_' + str(i+1)] * 2, ['Negative', 'Positive']])
#     df_conf = pd.DataFrame(conf_mat[i], index=['Other', 'Sub'], columns=['a', 'b'])
#     df_conf.columns = pd.MultiIndex.from_tuples(zip(['Sub_' + str(i+1)] * 2, df_conf.columns)) 
#     df_conf.index = ['Other', 'Sub']
#     df_conf.columns = pd.MultiIndex.from_product([['Sub_' + str(i+1)],'0'])
    df_conf.to_excel(writer, sheet_name='Conf_Mat', startrow=conf_row, startcol=conf_col)
    conf_col += 4
    if i == 2:
        conf_row += 6
        conf_col = 0
    elif i == 5:
        conf_row += 6
        conf_col = 0
    elif i == 8:
        conf_row += 6
        conf_col = 0


# Test_Loss
df_loss = pd.DataFrame(loss)
df_loss = df_loss.transpose()

# Test_Accuracy
df_acc = pd.DataFrame(acc)
df_acc = df_acc.transpose()

# Test_Sensitivitiy
df_sen = pd.DataFrame(sen)
df_sen = df_sen.transpose()

# Test_Specificity
df_spe = pd.DataFrame(spe)
df_spe = df_spe.transpose()

# Test_Precision
df_pre = pd.DataFrame(pre)
df_pre = df_pre.transpose()

# Test_Predict 값 채우기
for i in range(test_sub_cnt) :
    column = ('Predict_' + str(i + 1))
    df_predict[column] = predict[:, i]
    
# 칼럼 배열 ['Sub_1', 'Sub_2', ...]
col = []
for i in range(test_sub_cnt) :
    column = ('Sub_' + str(i + 1))
    col.append(column)
col = np.array(col)

# 각 데이터 프레임의 칼럼과 인덱스 설정
df_loss.columns = col
df_loss.index = ['Test_Loss']
df_acc.index = ['Test_Accuracy']
df_sen.columns = col
df_sen.index = ['Test_Sensitivity']
df_spe.index = ['Test_Speicificity']
df_pre.columns = col
df_pre.index = ['Test_Presicion']

# 모든 데이터 프레임 저장

df_predict.to_excel(writer, sheet_name='Predict', index=False, startrow=1)
# df_conf.to_excel(writer, sheet_name='Conf_Mat')

# Result Sheet
row = 0
df_loss.to_excel(writer, sheet_name='Result', startrow = row)
row += df_loss.shape[0] + 1
df_acc.to_excel(writer, sheet_name='Result', header=None, startrow=row)
row += df_acc.shape[0] + 3
df_sen.to_excel(writer, sheet_name='Result', startrow=row)
row += df_sen.shape[0] + 1
df_spe.to_excel(writer, sheet_name='Result', header=None, startrow=row)
row += df_spe.shape[0] + 3
df_pre.to_excel(writer, sheet_name='Result', startrow=row)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# 11
# 422
# 1
